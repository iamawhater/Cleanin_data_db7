# %%
data_set = r"C:\Users\alokd\Downloads\Water-Qual-Eau-Sites-National.csv"

# %%
import pandas as pd

# %%
data_set = r"C:\Users\alokd\Downloads\Water-Qual-Eau-Sites-National.csv"
df = pd.read_csv(data_set,encoding='latin-1')
df.head()
# Out:
#    SITE_NO                                          SITE_NAME  \
# 0       72  BEAUHARNOIS CANAL AT RTE 132 BRIDGE IN VALLEYF...
# 1       75  ST.LAWRENCE RIVER WATER INTAKE AT THE WATER PL...
# 2       78  ST.LAWRENCE RIVER WATER INTAKE AT THE WATER PL...
# 3  2330001   ETCHEMIN RIVER AT BRIDGE - RTE 132 IN ST-ROMUALD
# 4  2340033  CHAUDIÈRE RIVER AT CHARNY WATER INTAKE - 5.6 K...
#
#                                          SITE_NOM_FR      SITE_TYPE SITE_DESC  \
# 0  CANAL DE BEAUHARNOIS AU PONT-ROUTE 132 À VALLE...  RIVER/RIVIÈRE       NaN
# 1  FLEUVE SAINT-LAURENT À LA PRISE D'EAU DE L'USI...  RIVER/RIVIÈRE       NaN
# 2  FLEUVE SAINT-LAURENT À LA PRISE D'EAU DE L'USI...  RIVER/RIVIÈRE       NaN
# 3  RIVIÈRE ETCHEMIN AU PONT-ROUTE 132 À SAINT-ROM...  RIVER/RIVIÈRE       NaN
# 4  RIVIÈRE CHAUDIÈRE À LA PRISE D'EAU DE CHARNY À...  RIVER/RIVIÈRE       NaN
#
#   SITE_DESC_FR   LATITUDE  LONGITUDE  DATUM PROV_TERR      PEARSEDA  \
# ...

# %%
df.drop(['DATA_URL','DATA_URL_FR'], axis=1, inplace=True)

# %%
df.head()
# Out:
#    SITE_NO                                          SITE_NAME  \
# 0       72  BEAUHARNOIS CANAL AT RTE 132 BRIDGE IN VALLEYF...
# 1       75  ST.LAWRENCE RIVER WATER INTAKE AT THE WATER PL...
# 2       78  ST.LAWRENCE RIVER WATER INTAKE AT THE WATER PL...
# 3  2330001   ETCHEMIN RIVER AT BRIDGE - RTE 132 IN ST-ROMUALD
# 4  2340033  CHAUDIÈRE RIVER AT CHARNY WATER INTAKE - 5.6 K...
#
#                                          SITE_NOM_FR      SITE_TYPE SITE_DESC  \
# 0  CANAL DE BEAUHARNOIS AU PONT-ROUTE 132 À VALLE...  RIVER/RIVIÈRE       NaN
# 1  FLEUVE SAINT-LAURENT À LA PRISE D'EAU DE L'USI...  RIVER/RIVIÈRE       NaN
# 2  FLEUVE SAINT-LAURENT À LA PRISE D'EAU DE L'USI...  RIVER/RIVIÈRE       NaN
# 3  RIVIÈRE ETCHEMIN AU PONT-ROUTE 132 À SAINT-ROM...  RIVER/RIVIÈRE       NaN
# 4  RIVIÈRE CHAUDIÈRE À LA PRISE D'EAU DE CHARNY À...  RIVER/RIVIÈRE       NaN
#
#   SITE_DESC_FR   LATITUDE  LONGITUDE  DATUM PROV_TERR      PEARSEDA  \
# ...

# %%
df.drop(['SITE_NOM_FR','SITE_DESC_FR','PEARSEDA_FR','OCEANDA_FR'], axis=1, inplace=True)

# %%
df.head()
# Out:
#    SITE_NO                                          SITE_NAME      SITE_TYPE  \
# 0       72  BEAUHARNOIS CANAL AT RTE 132 BRIDGE IN VALLEYF...  RIVER/RIVIÈRE
# 1       75  ST.LAWRENCE RIVER WATER INTAKE AT THE WATER PL...  RIVER/RIVIÈRE
# 2       78  ST.LAWRENCE RIVER WATER INTAKE AT THE WATER PL...  RIVER/RIVIÈRE
# 3  2330001   ETCHEMIN RIVER AT BRIDGE - RTE 132 IN ST-ROMUALD  RIVER/RIVIÈRE
# 4  2340033  CHAUDIÈRE RIVER AT CHARNY WATER INTAKE - 5.6 K...  RIVER/RIVIÈRE
#
#   SITE_DESC   LATITUDE  LONGITUDE  DATUM PROV_TERR      PEARSEDA   OCEANDA
# 0       NaN  45.224068 -74.115648  NAD83        QC  ST. LAWRENCE  ATLANTIC
# 1       NaN  45.855776 -73.243925  NAD83        QC  ST. LAWRENCE  ATLANTIC
# 2       NaN  45.412863 -73.634724  NAD83        QC  ST. LAWRENCE  ATLANTIC
# 3       NaN  46.760140 -71.228209  NAD83        QC  ST. LAWRENCE  ATLANTIC
# 4       NaN  46.701956 -71.280756  NAD83        QC  ST. LAWRENCE  ATLANTIC

# %%
df.drop(['SITE_DESC'], axis=1, inplace=True)

# %%
df.head()
# Out:
#    SITE_NO                                          SITE_NAME      SITE_TYPE  \
# 0       72  BEAUHARNOIS CANAL AT RTE 132 BRIDGE IN VALLEYF...  RIVER/RIVIÈRE
# 1       75  ST.LAWRENCE RIVER WATER INTAKE AT THE WATER PL...  RIVER/RIVIÈRE
# 2       78  ST.LAWRENCE RIVER WATER INTAKE AT THE WATER PL...  RIVER/RIVIÈRE
# 3  2330001   ETCHEMIN RIVER AT BRIDGE - RTE 132 IN ST-ROMUALD  RIVER/RIVIÈRE
# 4  2340033  CHAUDIÈRE RIVER AT CHARNY WATER INTAKE - 5.6 K...  RIVER/RIVIÈRE
#
#     LATITUDE  LONGITUDE  DATUM PROV_TERR      PEARSEDA   OCEANDA
# 0  45.224068 -74.115648  NAD83        QC  ST. LAWRENCE  ATLANTIC
# 1  45.855776 -73.243925  NAD83        QC  ST. LAWRENCE  ATLANTIC
# 2  45.412863 -73.634724  NAD83        QC  ST. LAWRENCE  ATLANTIC
# 3  46.760140 -71.228209  NAD83        QC  ST. LAWRENCE  ATLANTIC
# 4  46.701956 -71.280756  NAD83        QC  ST. LAWRENCE  ATLANTIC

# %%
df.dtypes
# Out:
# SITE_NO       object
# SITE_NAME     object
# SITE_TYPE     object
# LATITUDE     float64
# LONGITUDE    float64
# DATUM         object
# PROV_TERR     object
# PEARSEDA      object
# OCEANDA       object
# dtype: object
